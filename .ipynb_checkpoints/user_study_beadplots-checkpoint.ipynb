# %%
import pandas as pd
import numpy as np
import altair as alt

from collections import OrderedDict

# %%
def generate_beadplot(data_csv, title, num_citations):
    data = pd.read_csv(data_csv)
    # data['algo_score_raw'] = data['algo_score_raw'].replace({0: -1})
    # display(data)
    # First generate base graph
    base = alt.Chart(data, title=f"{title}, {num_citations} Citations").mark_circle(opacity=1, stroke='#4c78a8').encode(
        x=alt.X('Paragraph:N', axis=alt.Axis(labelAngle=0)),
        y=alt.Y('Section:N', sort=list(OrderedDict.fromkeys(data['Section']))),
        size=alt.Size('algo_score_raw:Q', title="Number of Matches"), # ordinal variable type so legend not continuous
    ).properties(
        width=900,
        height=500
    )
    
    # Next generate the overlying graph with the lines
    
    lines = alt.Chart(data).mark_rule(stroke='#4c78a8').encode(
        x=alt.X('Paragraph:N', axis=alt.Axis(labelAngle=0)),
        y=alt.Y('Section:N', sort=list(OrderedDict.fromkeys(data['Section'])))
    ).properties(
        width=900,
        height=500
    )
    if max(data['algo_score_raw']) == 0:
        return lines # no beads if no matches
    else:
        return base + lines

# %% [markdown]
# ### Women in HCI India Paper
# Keywords: gender

# %%
generate_beadplot('./output/women_computing_india-marriage-matrimony-married_couple-marriage_ceremony-wedlock-wedding-man_and_wife-spousal_relationship-marriage-union.csv',
                 "The Unexpected Entry and Exodus of Women in Computing and HCI in India",
                 14)
# Out:
# alt.LayerChart(...)

# %% [markdown]
# ### Women in HCI India Paper
# Keywords: gender, sex

# %%
generate_beadplot('./output/women_computing_india-education-pedagogy-instruction-teaching-educational_activity.csv',
                 "The Unexpected Entry and Exodus of Women in Computing and HCI in India",
                 14)
# Out:
# alt.LayerChart(...)

# %% [markdown]
# ### Women in HCI India Paper
# Keywords: gender, gender stereotypes

# %%
generate_beadplot('./output/women_computing_india-gender-sex.csv',
                  "The Unexpected Entry and Exodus of Women in Computing and HCI in India",
                 14)
# Out:
# alt.LayerChart(...)

# %% [markdown]
# ### Women in HCI India Paper
# Keywords: gender, gender roles

# %%
generate_beadplot('./output/women_computing_india-gender discrimination-gender favoritism-sex discrimination-sex favoritism.csv',
                  "The Unexpected Entry and Exodus of Women in Computing and HCI in India",
                 14)
# Out:
# alt.LayerChart(...)

# %% [markdown]
# ### Women in HCI India Paper
# Keywords: gender, gender roles, sex

# %%
generate_beadplot('./output/women_computing_india-pursue computer science-pursue computer skill-quest_for computer science-follow computer science-go_after computer science-follow computer skill.csv',
                 "The Unexpected Entry and Exodus of Women in Computing and HCI in India",
                 14)
# Out:
# alt.Chart(...)

# %% [markdown]
# ### Women in HCI India Paper
# Keywords: gender, gender roles, gender stereotypes

# %%
generate_beadplot('./output/women_computing_india-human computer interaction-human computer fundamental_interaction-human_being computer interaction-man computer interaction.csv',
                  "The Unexpected Entry and Exodus of Women in Computing and HCI in India",
                 14)
# Out:
# alt.LayerChart(...)

# %% [markdown]
# ### Women in HCI India Paper
# Keywords: gender, sex, gender stereotypes

# %% [markdown]
# ### Women in HCI India Paper
# Keywords: gender, gender roles, sex gender stereotypes

# %% [markdown]
# ### Bitcoin Paper
# Keywords: limit, limitation

# %%
generate_beadplot('./output/bitcoin-limitation-limit.csv',
                  "Exploring Trust in Bitcoin Technology: A Framework for HCI Research",
                 69)
# Out:
# alt.LayerChart(...)

# %% [markdown]
# ### Bitcoin Paper
# Keywords: limitation, shortcoming, lack, fail

# %%
generate_beadplot('./output/bitcoin-limitation-shortcoming-lack-fail.csv',
                  "Exploring Trust in Bitcoin Technology: A Framework for HCI Research",
                 69)
# Out:
# alt.LayerChart(...)

# %% [markdown]
# ### Bitcoin Paper
# Keywords: framework structure, organization, model, layout

# %%
generate_beadplot('./output/bitcoin-framework-structure-organization-model-layout.csv',
                  "Exploring Trust in Bitcoin Technology: A Framework for HCI Research",
                 69)
# Out:
# alt.LayerChart(...)
